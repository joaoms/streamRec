# %%
import os
import sys
sys.path.append(os.path.abspath('') + '/..')

# %%
from data import ImplicitData
import pandas as pd
import numpy as np
from recommenders_implicit import UBISGD
from eval_implicit import EvalPrequential
from datetime import datetime

# %%
data = pd.read_csv("datasets/ymusic_gte90_6kusers.tsv","\t")
stream = ImplicitData(data['user_id'],data['item_id'])

# %%
num_factors = 200
num_iter = 9
learn_rate = 0.25
regularization = 0.45
num_nodes = 8

# %%
model = UBISGD(ImplicitData([],[]), num_factors, num_iter, num_nodes, learn_rate = learn_rate, u_regularization = regularization, i_regularization = regularization, random_seed = 10)
#model = BISGD(ImplicitData([],[]),90, 8, num_nodes, learn_rate = 0.3, u_regularization = 0.4, i_regularization = 0.4, use_numba = False)

# %%
eval = EvalPrequential(model,stream, metrics = ["Recall@20"])

# %%
start_recommend = datetime.now()
print('start time', start_recommend)

results=eval.EvaluateTime(0,stream.size, 100)

print('npmean(resuls[Recall@20])', np.mean(results['Recall@20']))
# Out:
# start time 2021-02-17 08:34:56.471758
# .npmean(resuls[Recall@20]) 0.12937722793038373

# %%
end_recommend = datetime.now()
print('end time', end_recommend)

tempo = end_recommend - start_recommend

print('run time', tempo)
print('')
print('get tuple',np.mean(results['time_get_tuple']))
print('recommend',np.mean(results['time_recommend']))
print('eval_point',np.mean(results['time_eval_point']))
print('update',np.mean(results['time_update']))
# Out:
# end time 2021-02-17 14:07:59.738329
# run time 5:33:03.266571
#
# get tuple 0.00020122646464045563
# recommend 3.6577688907272137
# eval_point 8.907486093096775e-05
# update 0.005109413075603967

# %%
sum(results['Recall@20'])/len(results['Recall@20'])
# Out:
# 0.12937722793038373
